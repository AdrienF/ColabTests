# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrienF/ColabTests/blob/main/NotebookTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
!

# %% [markdown]
# Mon premier notebook

# %%
import pandas as pd
# !wget https://raw.githubusercontent.com/AdrienF/ColabTests/main/mushrooms.csv
df = pd.read_csv("mushrooms.csv")
# Out:
# --2021-01-04 14:53:41--  https://raw.githubusercontent.com/AdrienF/ColabTests/main/mushrooms.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 374003 (365K) [text/plain]
# Saving to: ‘mushrooms.csv.1’
#
# mushrooms.csv.1     100%[===================>] 365.24K  --.-KB/s    in 0.05s
#
# 2021-01-04 14:53:41 (6.77 MB/s) - ‘mushrooms.csv.1’ saved [374003/374003]

# %%
df
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 0        p         x           s  ...                 k          s       u
# 1        e         x           s  ...                 n          n       g
# 2        e         b           s  ...                 n          n       m
# 3        p         x           y  ...                 k          s       u
# 4        e         x           s  ...                 n          a       g
# ...    ...       ...         ...  ...               ...        ...     ...
# 8119     e         k           s  ...                 b          c       l
# 8120     e         x           s  ...                 b          v       l
# 8121     e         f           s  ...                 b          c       l
# 8122     p         k           y  ...                 w          v       l
# 8123     e         x           s  ...                 o          c       l
#
# [8124 rows x 23 columns]
